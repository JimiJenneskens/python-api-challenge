# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from api_keys import weather_api_key
from citipy import citipy

# csv
output_data_file = "../output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 647

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# query url
base_url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{base_url}appid={weather_api_key}&units=imperial&q="

# empty lists to store data
city_name =[] 
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

count_record = 0
count_set = 1

print("Beginning Data Retrieval")
print("------------------------")

# loop through cities and request data
for city in cities:
    if count_record > 49: 
        count_set += 1
        count_record = 0
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temperature.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        print(f"Processing Record {count_record} of Set {count_set} | {city}")
        count_record += 1
        
    except:
        print(f"City not found. Skipping... ")
        
print("------------------------")
print("Data Retrieval Complete ")
print("------------------------")    

# put data in dataframe
cities_df = pd.DataFrame({'City' : city_name,
                          'Lat' : latitude,
                          'Lng' : longitude,
                          'Max Temp' : max_temperature,
                          'Humidity' : humidity,
                          'Cloudiness' : cloudiness,
                          'Wind Speed' : wind_speed,
                          'Country' : country,
                          'Date' : date})
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 of Set 1 | qaanaaq
# Processing Record 1 of Set 1 | tadine
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | san rafael
# Processing Record 5 of Set 1 | laguna
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | qasigiannguit
# Processing Record 8 of Set 1 | wad rawah
# Processing Record 9 of Set 1 | saurimo
# Processing Record 10 of Set 1 | namatanai
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | dikson
# Processing Record 13 of Set 1 | ketchikan
# Processing Record 14 of Set 1 | bara
# Processing Record 15 of Set 1 | salinas
# Processing Record 16 of Set 1 | lebu
# Processing Record 17 of Set 1 | puerto ayora
# Processing Record 18 of Set 1 | suntar
# Processing Record 19 of Set 1 | hithadhoo
# Processing Record 20 of Set 1 | egvekinot
# Processing Record 21 of Set 1 | tuktoyaktuk
# Processing Record 22 of Set 1 | flin flon
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | ushuaia
# Processing Record 25 of Set 1 | geraldton
# Processing Record 26 of Set 1 | faanui
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | mayor pablo lagerenza
# Processing Record 29 of Set 1 | longyearbyen
# Processing Record 30 of Set 1 | bambous virieux
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | taoudenni
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | rocha
# Processing Record 35 of Set 1 | ventspils
# Processing Record 36 of Set 1 | trofors
# City not found. Skipping...
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | sao joao da barra
# Processing Record 39 of Set 1 | ilhabela
# Processing Record 40 of Set 1 | vila velha
# Processing Record 41 of Set 1 | te anau
# City not found. Skipping...
# Processing Record 42 of Set 1 | fenoarivo
# Processing Record 43 of Set 1 | port alfred
# City not found. Skipping...
# Processing Record 44 of Set 1 | puerto baquerizo moreno
# Processing Record 45 of Set 1 | mandurah
# Processing Record 46 of Set 1 | broome
# City not found. Skipping...
# Processing Record 47 of Set 1 | hamilton
# Processing Record 48 of Set 1 | busselton
# Processing Record 49 of Set 1 | hermanus
# Processing Record 0 of Set 2 | kupang
# Processing Record 1 of Set 2 | arraial do cabo
# Processing Record 2 of Set 2 | ixtapa
# Processing Record 3 of Set 2 | polyarnyy
# Processing Record 4 of Set 2 | nanortalik
# Processing Record 5 of Set 2 | coquimbo
# Processing Record 6 of Set 2 | alta floresta
# City not found. Skipping...
# Processing Record 7 of Set 2 | yar-sale
# Processing Record 8 of Set 2 | kaitangata
# Processing Record 9 of Set 2 | grindavik
# Processing Record 10 of Set 2 | beringovskiy
# Processing Record 11 of Set 2 | tabou
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 3 | tasiilaq
# Processing Record 46 of Set 3 | klaksvik
# City not found. Skipping...
# Processing Record 47 of Set 3 | cine
# Processing Record 48 of Set 3 | bartica
# Processing Record 49 of Set 3 | gudari
# Processing Record 0 of Set 4 | bilibino
# Processing Record 1 of Set 4 | poroina mare
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | tuatapere
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | villeneuve-sur-lot
# Processing Record 6 of Set 4 | chokurdakh
# Processing Record 7 of Set 4 | barcelos
# Processing Record 8 of Set 4 | maun
# Processing Record 9 of Set 4 | yarim
# Processing Record 10 of Set 4 | japura
# Processing Record 11 of Set 4 | itarema
# Processing Record 12 of Set 4 | raga
# Processing Record 13 of Set 4 | shenzhen
# Processing Record 14 of Set 4 | husavik
# Processing Record 15 of Set 4 | khor
# Processing Record 16 of Set 4 | cape town
# Processing Record 17 of Set 4 | nelson bay
# Processing Record 18 of Set 4 | surt
# Processing Record 19 of Set 4 | avera
# Processing Record 20 of Set 4 | nhulunbuy
# Processing Record 21 of Set 4 | san vicente
# Processing Record 22 of Set 4 | carira
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 4 | souillac
# Processing Record 24 of Set 4 | aripuana
# Processing Record 25 of Set 4 | galle
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | negombo
# Processing Record 28 of Set 4 | aksarka
# Processing Record 29 of Set 4 | sangar
# Processing Record 30 of Set 4 | mandan
# Processing Record 31 of Set 4 | butaritari
# Processing Record 32 of Set 4 | orocue
# Processing Record 33 of Set 4 | chicama
# Processing Record 34 of Set 4 | mogadishu
# Processing Record 35 of Set 4 | sarangani
# Processing Record 36 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 4 | victoria
# Processing Record 38 of Set 4 | mezen
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | guilin
# Processing Record 41 of Set 4 | sao jose da coroa grande
# City not found. Skipping...
# Processing Record 42 of Set 4 | araceli
# Processing Record 43 of Set 4 | buala
# Processing Record 44 of Set 4 | mugumu
# Processing Record 45 of Set 4 | beaver dam
# Processing Record 46 of Set 4 | ericeira
# Processing Record 47 of Set 4 | norman wells
# City not found. Skipping...
# Processing Record 48 of Set 4 | avarua
# Processing Record 49 of Set 4 | chivilcoy
# Processing Record 0 of Set 5 | ahuimanu
# Processing Record 1 of Set 5 | mar del plata
# Processing Record 2 of Set 5 | belmonte
# Processing Record 3 of Set 5 | ecublens
# City not found. Skipping...
# Processing Record 4 of Set 5 | ratnagiri
# Processing Record 5 of Set 5 | joaima
# Processing Record 6 of Set 5 | trincomalee
# City not found. Skipping...
# Processing Record 7 of Set 5 | salalah
# Processing Record 8 of Set 5 | cidreira
# Processing Record 9 of Set 5 | hammerfest
# Processing Record 10 of Set 5 | lagos
# Processing Record 11 of Set 5 | kaka
# Processing Record 12 of Set 5 | saint-pierre
# Processing Record 13 of Set 5 | abu zabad
# Processing Record 14 of Set 5 | kijang
# City not found. Skipping...
# Processing Record 15 of Set 5 | skagen
# Processing Record 16 of Set 5 | slave lake
# City not found. Skipping...
# Processing Record 17 of Set 5 | trenggalek
# Processing Record 18 of Set 5 | dunedin
# Processing Record 19 of Set 5 | lagoa
# Processing Record 20 of Set 5 | nikolskoye
# Processing Record 21 of Set 5 | katsuura
# Processing Record 22 of Set 5 | the pas
# Processing Record 23 of Set 5 | acopiara
# Processing Record 24 of Set 5 | bokoro
# Processing Record 25 of Set 5 | takoradi
# Processing Record 26 of Set 5 | sawakin
# Processing Record 27 of Set 5 | el tigre
# Processing Record 28 of Set 5 | ithaki
# Processing Record 29 of Set 5 | guerrero negro
# Processing Record 30 of Set 5 | krasnoselkup
# Processing Record 31 of Set 5 | tautira
# Processing Record 32 of Set 5 | lasa
# Processing Record 33 of Set 5 | kaohsiung
# Processing Record 34 of Set 5 | los llanos de aridane
# Processing Record 35 of Set 5 | bambanglipuro
# Processing Record 36 of Set 5 | aktau
# Processing Record 37 of Set 5 | nuevo progreso
# Processing Record 38 of Set 5 | sorong
# Processing Record 39 of Set 5 | north bend
# Processing Record 40 of Set 5 | cozumel
# Processing Record 41 of Set 5 | evensk
# Processing Record 42 of Set 5 | barrow
# Processing Record 43 of Set 5 | tiksi
# Processing Record 44 of Set 5 | beatrice
# Processing Record 45 of Set 5 | goma
# Processing Record 46 of Set 5 | pevek
# Processing Record 47 of Set 5 | kikwit
# Processing Record 48 of Set 5 | yola
# Processing Record 49 of Set 5 | upernavik
# Processing Record 0 of Set 6 | san martin
# Processing Record 1 of Set 6 | tessalit
# Processing Record 2 of Set 6 | fortuna
# Processing Record 3 of Set 6 | kuji
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | constitucion
# Processing Record 6 of Set 6 | kaeo
# Processing Record 7 of Set 6 | pisco
# Processing Record 8 of Set 6 | ozernovskiy
# Processing Record 9 of Set 6 | nyurba
# Processing Record 10 of Set 6 | kotaparh
# Processing Record 11 of Set 6 | karpathos
# Processing Record 12 of Set 6 | hwange
# Processing Record 13 of Set 6 | boende
# Processing Record 14 of Set 6 | port hawkesbury
# Processing Record 15 of Set 6 | severo-kurilsk
# Processing Record 16 of Set 6 | santa maria
# Processing Record 17 of Set 6 | san policarpo
# Processing Record 18 of Set 6 | sao gabriel da cachoeira
# Processing Record 19 of Set 6 | hurricane
# Processing Record 20 of Set 6 | khatanga
# Processing Record 21 of Set 6 | morshansk
# Processing Record 22 of Set 6 | ambanja
# Processing Record 23 of Set 6 | kodiak
# Processing Record 24 of Set 6 | salinopolis
# Processing Record 25 of Set 6 | darhan
# Processing Record 26 of Set 6 | college
# Processing Record 27 of Set 6 | vanimo
# Processing Record 28 of Set 6 | oxbow
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 6 | lata
# Processing Record 30 of Set 6 | thatta
# Processing Record 31 of Set 6 | san juan
# Processing Record 32 of Set 6 | lodja
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 6 | igarka
# Processing Record 34 of Set 6 | ouesso
# Processing Record 35 of Set 6 | dekar
# Processing Record 36 of Set 6 | opuwo
# Processing Record 37 of Set 6 | uruguaiana
# City not found. Skipping...
# Processing Record 38 of Set 6 | marsh harbour
# Processing Record 39 of Set 6 | yellowknife
# Processing Record 40 of Set 6 | concarneau
# Processing Record 41 of Set 6 | tocopilla
# Processing Record 42 of Set 6 | seoul
# Processing Record 43 of Set 6 | lavrentiya
# Processing Record 44 of Set 6 | alofi
# Processing Record 45 of Set 6 | maroua
# Processing Record 46 of Set 6 | airai
# Processing Record 47 of Set 6 | sorland
# Processing Record 48 of Set 6 | panguna
# Processing Record 49 of Set 6 | fairbanks
# Processing Record 0 of Set 7 | upata
# Processing Record 1 of Set 7 | black river
# Processing Record 1 of Set 10 | codrington
# Processing Record 2 of Set 10 | adrar
# Processing Record 3 of Set 10 | tukrah
# Processing Record 4 of Set 10 | chapais
# City not found. Skipping...
# Processing Record 5 of Set 10 | gizo
# Processing Record 6 of Set 10 | pacifica
# Processing Record 7 of Set 10 | cabedelo
# City not found. Skipping...
# Processing Record 8 of Set 10 | mount gambier
# Processing Record 9 of Set 10 | port hardy
# Processing Record 10 of Set 10 | tiruchchendur
# Processing Record 11 of Set 10 | payo
# Processing Record 12 of Set 10 | pelym
# Processing Record 13 of Set 10 | cap malheureux
# Processing Record 14 of Set 10 | uray
# Processing Record 15 of Set 10 | bitung
# Processing Record 16 of Set 10 | hay river
# Processing Record 17 of Set 10 | morehead
# Processing Record 18 of Set 10 | prescott
# Processing Record 19 of Set 10 | port-gentil
# Processing Record 20 of Set 10 | indiaroba
# Processing Record 21 of Set 10 | ranong
# Processing Record 22 of Set 10 | russell
# City not found. Skipping...
# Processing Record 23 of Set 10 | zhigansk
# Processing Record 24 of Set 10 | maracacume
# City not found. Skipping...
# Processing Record 25 of Set 10 | monrovia
# Processing Record 26 of Set 10 | piranshahr
# Processing Record 27 of Set 10 | whitehorse
# Processing Record 28 of Set 10 | chlorakas
# Processing Record 29 of Set 10 | nioki
# Processing Record 30 of Set 10 | terme
# Processing Record 31 of Set 10 | sao felix do xingu
# Processing Record 32 of Set 10 | bima
# Processing Record 33 of Set 10 | wisconsin rapids
# Processing Record 34 of Set 10 | flinders
# Processing Record 35 of Set 10 | thinadhoo
# Processing Record 36 of Set 10 | peniche
# Processing Record 37 of Set 10 | phangnga
# Processing Record 38 of Set 10 | bowmore
# Processing Record 39 of Set 10 | haines junction
# Processing Record 40 of Set 10 | ust-koksa
# Processing Record 41 of Set 10 | chengde
# Processing Record 42 of Set 10 | aasiaat
# Processing Record 43 of Set 10 | narsaq
# Processing Record 44 of Set 10 | puruliya
# Processing Record 45 of Set 10 | lakes entrance
# Processing Record 46 of Set 10 | challans
# City not found. Skipping...
# Processing Record 47 of Set 10 | buraydah
# Processing Record 48 of Set 10 | florence
# Processing Record 49 of Set 10 | storforshei
# Processing Record 0 of Set 11 | vestmanna
# Processing Record 1 of Set 11 | zagora
# Processing Record 2 of Set 11 | winnemucca
# Processing Record 3 of Set 11 | olinda
# Processing Record 4 of Set 11 | kimbe
# Processing Record 5 of Set 11 | shahapur
# Processing Record 6 of Set 11 | iqaluit
# Processing Record 7 of Set 11 | french harbor
# Processing Record 8 of Set 11 | miraflores
# Processing Record 9 of Set 11 | elk city
# City not found. Skipping...
# Processing Record 10 of Set 11 | comodoro rivadavia
# Processing Record 11 of Set 11 | mount isa
# Processing Record 12 of Set 11 | arawa
# City not found. Skipping...
# Processing Record 13 of Set 11 | yuncheng
# Processing Record 14 of Set 11 | ambilobe
# Processing Record 15 of Set 11 | bathsheba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 16 of Set 11 | rundu
# Processing Record 17 of Set 11 | san patricio
# Processing Record 18 of Set 11 | kwidzyn
# Processing Record 19 of Set 11 | irtyshskiy
# City not found. Skipping...
# Processing Record 20 of Set 11 | broken hill
# Processing Record 21 of Set 11 | ust-nera
# Processing Record 22 of Set 11 | gejiu
# Processing Record 23 of Set 11 | impfondo
# Processing Record 24 of Set 11 | vila franca do campo
# Processing Record 25 of Set 11 | nikki
# Processing Record 26 of Set 11 | monte alto
# Processing Record 27 of Set 11 | manzanillo
# Processing Record 28 of Set 11 | pontal do parana
# Processing Record 29 of Set 11 | norfolk
# Processing Record 30 of Set 11 | makat
# Processing Record 31 of Set 11 | la palma
# Processing Record 32 of Set 11 | mawlaik
# Processing Record 33 of Set 11 | sioux lookout
# Processing Record 34 of Set 11 | jati
# Processing Record 35 of Set 11 | solnechnyy
# Processing Record 36 of Set 11 | porto belo
# Processing Record 37 of Set 11 | farafangana
# Processing Record 38 of Set 11 | aban
# Processing Record 39 of Set 11 | daru
# Processing Record 40 of Set 11 | karaton
# Processing Record 41 of Set 11 | varhaug
# Processing Record 42 of Set 11 | kilindoni
# City not found. Skipping...
# Processing Record 43 of Set 11 | eureka
# Processing Record 44 of Set 11 | bairiki
# Processing Record 45 of Set 11 | griffith
# City not found. Skipping...
# Processing Record 46 of Set 11 | chernyshevskiy
# Processing Record 47 of Set 11 | liepaja
# Processing Record 48 of Set 11 | ouahigouya
# Processing Record 49 of Set 11 | abnub
# Processing Record 0 of Set 12 | nouadhibou
# Processing Record 1 of Set 12 | coos bay
# Processing Record 2 of Set 12 | grootfontein
# Processing Record 3 of Set 12 | scottsbluff
# Processing Record 4 of Set 12 | coahuayana
# Processing Record 5 of Set 12 | saldanha
# Processing Record 6 of Set 12 | vila do maio
# Processing Record 7 of Set 12 | parana
# Processing Record 8 of Set 12 | volgodonsk
# City not found. Skipping...
# Processing Record 9 of Set 12 | berkovica
# Processing Record 10 of Set 12 | naze
# Processing Record 11 of Set 12 | mahibadhoo
# Processing Record 12 of Set 12 | enterprise
# Processing Record 13 of Set 12 | datong
# City not found. Skipping...
# Processing Record 14 of Set 12 | warrnambool
# Processing Record 15 of Set 12 | forio
# Processing Record 16 of Set 12 | spenge
# Processing Record 17 of Set 12 | maragogi
# Processing Record 18 of Set 12 | byron bay
# Processing Record 19 of Set 12 | terny
# Processing Record 20 of Set 12 | champerico
# Processing Record 21 of Set 12 | ancud
# Processing Record 22 of Set 12 | beysehir
# Processing Record 23 of Set 12 | kade
# Processing Record 24 of Set 12 | barbosa ferraz
# Processing Record 25 of Set 12 | novikovo
# Processing Record 26 of Set 12 | carnduff
# Processing Record 27 of Set 12 | mnogovershinnyy
# City not found. Skipping...
# Processing Record 28 of Set 12 | kenmare
# Processing Record 29 of Set 12 | iracoubo
# Processing Record 30 of Set 12 | teguldet
# Processing Record 31 of Set 12 | jos
# Processing Record 32 of Set 12 | iisalmi
# Processing Record 33 of Set 12 | odweyne
# Processing Record 34 of Set 12 | masterton
# Processing Record 35 of Set 12 | hami
# Processing Record 36 of Set 12 | boa vista
# Processing Record 37 of Set 12 | roma
# Processing Record 38 of Set 12 | vuktyl
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv(output_data_file)
cities_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Qaanaaq  77.48  -69.36     28.80        85          92        3.44
# 1      Tadine -21.55  167.88     65.84        67         100       18.34
# 2      Albany  42.60  -73.97     77.58        49         100        1.52
# 3     Mataura -46.19  168.86     45.00        72         100       11.01
# 4  San Rafael -34.62  -68.33     67.73        23           0        8.19
#
#   Country        Date
# 0      GL  1599158577
# 1      NC  1599158578
# 2      US  1599158347
# 3      NZ  1599158578
# 4      AR  1599158318

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_df["Humidity"].max()

# There is no Humidity over 100, so all of this is not necessary
# Out:
# 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# put axes
lat = cities_df["Lat"]
max_temp = cities_df["Max Temp"]

# plot
plt.scatter(lat, max_temp, marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Max Temperature (08/31/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()

# save
plt.savefig("CityLatitudeVsMaxTemperature.png")

# show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# put axes
humid = cities_df["Humidity"]

# plot
plt.scatter(lat, humid, marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Humidity (08/31/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

# save
plt.savefig("CityLatitudeVsHumidity.png")

# show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# put axes
cloud = cities_df["Cloudiness"]

# plot
plt.scatter(lat, cloud, marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Cloudiness (08/31/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# save
plt.savefig("CityLatitudeVsCloudiness.png")

# show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# put axes
wind = cities_df["Wind Speed"]

# plot
plt.scatter(lat, wind, marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Wind Speed (08/31/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()

# save
plt.savefig("CityLatitudeVsWindSpeed.png")

# show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# create new df's for northern and southern hempishere
north_hem_df = cities_df[cities_df['Lat'] > 0]
south_hem_df = cities_df[cities_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
from scipy.stats import linregress

x_value = north_hem_df['Lat']
y_value = north_hem_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (10, 40), color='red', fontsize= 14)
plt.title("Northern Hemisphere - Max Temp vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid()
plt.savefig("NorthMaxTempVsLat.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.6223953177945853

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = south_hem_df['Lat']
y_value = south_hem_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (-50, 90), color='red', fontsize= 14)
plt.title("Southern Hemisphere - Max Temp vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid()
plt.savefig("SouthMaxTempVsLat.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.6278729494795046

# %%
#Conclusion 1

print("Conclusion 1: The highest maximum temperatures are near the 0 value of the Latitude")
# Out:
# Conclusion 1: The highest maximum temperatures are near the 0 value of the Latitude

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = north_hem_df['Lat']
y_value = north_hem_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (50, 10), color='red', fontsize= 14)
plt.title("Northern Hemisphere - Humidity vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("NorthHumVsLat.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.008650185812590867

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = south_hem_df['Lat']
y_value = south_hem_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (-50, 10), color='red', fontsize= 14)
plt.title("Southern Hemisphere - Humidity vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.savefig("SouthHumVsLat.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 8.856837356930288e-05

# %%
#Conclusion 2

print("Conclusion 2: Humidity and Latitude are not correlated")
# Out:
# Conclusion 2: Humidity and Latitude are not correlated

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = north_hem_df['Lat']
y_value = north_hem_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (8, 30), color='red', fontsize= 14)
plt.title("Northern Hemisphere - Cloudiness vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("NorthCloudVsLat.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.00032599537728584724

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = south_hem_df['Lat']
y_value = south_hem_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (-50, 26), color='red', fontsize= 14)
plt.title("Southern Hemisphere - Cloudiness vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.savefig("SouthCloudVsLat.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.0007128915602106936

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = north_hem_df['Lat']
y_value = north_hem_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (18, 26), color='red', fontsize= 14)
plt.title("Northern Hemisphere - Wind Speed vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("NorthWindVsLat.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.015060831778509176

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = south_hem_df['Lat']
y_value = south_hem_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (-47, 28), color='red', fontsize= 14)
plt.title("Southern Hemisphere - Wind Speed vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.savefig("SouthWindVsLat.png")
plt.show()

print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.003411254695916514

# %%
#Conclusion 3

print("Conclusion 3: There is no trend in the Wind Speed compared to the latitude")
# Out:
# Conclusion 3: There is no trend in the Wind Speed compared to the latitude
