# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from api_keys import weather_api_key
from citipy import citipy

# csv
output_data_file = "../output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 606

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# query url
base_url = "http://api.openweathermap.org/data/2.5/weather?"

query_url = f"{base_url}appid={weather_api_key}&units=imperial&q="

# empty lists to store data
city_name =[] 
latitude = []
longitude = []
max_temperature = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

count_record = 0
count_set = 1

print("Beginning Data Retrieval")
print("------------------------")

# loop through cities and request data
for city in cities:
    if count_record > 49: 
        count_set += 1
        count_record = 0
    try:
        response = requests.get(query_url + city).json()
        city_name.append(response['name'])
        latitude.append(response['coord']['lat'])
        longitude.append(response['coord']['lon'])
        max_temperature.append(response['main']['temp'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        
        print(f"Processing Record {count_record} of Set {count_set} | {city}")
        count_record += 1
        
    except:
        print(f"City not found. Skipping... ")
        
print("------------------------")
print("Data Retrieval Complete ")
print("------------------------")    

# put data in dataframe
cities_df = pd.DataFrame({'City' : city_name,
                          'Lat' : latitude,
                          'Lng' : longitude,
                          'Max Temp' : max_temperature,
                          'Humidity' : humidity,
                          'Cloudiness' : cloudiness,
                          'Wind Speed' : wind_speed,
                          'Country' : country,
                          'Date' : date})
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing Record 0 of Set 1 | bluff
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | dongzhen
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | bethel
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | coihaique
# Processing Record 7 of Set 1 | mar del plata
# Processing Record 8 of Set 1 | lakes entrance
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | pacific grove
# Processing Record 11 of Set 1 | cayenne
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | ribeira grande
# Processing Record 14 of Set 1 | tutoia
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | new norfolk
# Processing Record 17 of Set 1 | arman
# Processing Record 18 of Set 1 | aklavik
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | mpulungu
# Processing Record 21 of Set 1 | tuatapere
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | guerrero negro
# Processing Record 24 of Set 1 | barrow
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | roald
# Processing Record 28 of Set 1 | perle
# Processing Record 29 of Set 1 | lompoc
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | klaksvik
# Processing Record 32 of Set 1 | hermanus
# Processing Record 33 of Set 1 | arraial do cabo
# Processing Record 34 of Set 1 | saskylakh
# Processing Record 35 of Set 1 | bonavista
# Processing Record 36 of Set 1 | rafai
# Processing Record 37 of Set 1 | lianzhou
# Processing Record 38 of Set 1 | durusu
# City not found. Skipping...
# Processing Record 39 of Set 1 | bongandanga
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | moron
# City not found. Skipping...
# Processing Record 44 of Set 1 | rocha
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | ambilobe
# Processing Record 47 of Set 1 | norfolk
# Processing Record 48 of Set 1 | kamenka
# Processing Record 49 of Set 1 | saint-joseph
# Processing Record 0 of Set 2 | sorong
# City not found. Skipping...
# Processing Record 1 of Set 2 | upernavik
# Processing Record 2 of Set 2 | longkou
# Processing Record 3 of Set 2 | evensk
# Processing Record 4 of Set 2 | mataura
# Processing Record 5 of Set 2 | chara
# Processing Record 6 of Set 2 | cabo san lucas
# Processing Record 7 of Set 2 | mikhaylovka
# Processing Record 8 of Set 2 | port-gentil
# Processing Record 9 of Set 2 | hobyo
# City not found. Skipping...
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | fairbanks
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | ponta do sol
# Processing Record 14 of Set 2 | luderitz
# Processing Record 15 of Set 2 | winnenden
# City not found. Skipping...
# Processing Record 16 of Set 2 | merauke
# Processing Record 17 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record
# City not found. Skipping...
# Processing Record 4 of Set 4 | ilulissat
# Processing Record 5 of Set 4 | quelimane
# Processing Record 6 of Set 4 | atambua
# Processing Record 7 of Set 4 | chippewa falls
# Processing Record 8 of Set 4 | kodiak
# City not found. Skipping...
# Processing Record 9 of Set 4 | nacala
# Processing Record 10 of Set 4 | makakilo city
# Processing Record 11 of Set 4 | nautla
# City not found. Skipping...
# Processing Record 12 of Set 4 | huanan
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | tasiilaq
# Processing Record 15 of Set 4 | mwene-ditu
# City not found. Skipping...
# Processing Record 16 of Set 4 | amapa
# City not found. Skipping...
# Processing Record 17 of Set 4 | cerro largo
# Processing Record 18 of Set 4 | ler
# Processing Record 19 of Set 4 | bibiani
# Processing Record 20 of Set 4 | pevek
# Processing Record 21 of Set 4 | buala
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | kawalu
# Processing Record 24 of Set 4 | paracuru
# Processing Record 25 of Set 4 | wexford
# Processing Record 26 of Set 4 | najran
# Processing Record 27 of Set 4 | mafeteng
# Processing Record 28 of Set 4 | gloversville
# Processing Record 29 of Set 4 | misratah
# Processing Record 30 of Set 4 | plettenberg bay
# Processing Record 31 of Set 4 | kahului
# Processing Record 32 of Set 4 | vila do maio
# Processing Record 33 of Set 4 | malinyi
# Processing Record 34 of Set 4 | grand-santi
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | northam
# Processing Record 37 of Set 4 | airai
# City not found. Skipping...
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | ca mau
# City not found. Skipping...
# Processing Record 40 of Set 4 | calatayud
# Processing Record 41 of Set 4 | vestmanna
# Processing Record 42 of Set 4 | yaan
# Processing Record 43 of Set 4 | ilo
# City not found. Skipping...
# Processing Record 44 of Set 4 | concordia
# Processing Record 45 of Set 4 | huilong
# Processing Record 46 of Set 4 | fortuna
# Processing Record 47 of Set 4 | sabang
# Processing Record 48 of Set 4 | sao gabriel da cachoeira
# Processing Record 49 of Set 4 | lavrentiya
# City not found. Skipping...
# Processing Record 0 of Set 5 | kropotkin
# Processing Record 1 of Set 5 | pisco
# Processing Record 2 of Set 5 | greenfield
# Processing Record 3 of Set 5 | chulym
# Processing Record 4 of Set 5 | tilichiki
# Processing Record 5 of Set 5 | stephenville
# Processing Record 6 of Set 5 | walvis bay
# Processing Record 7 of Set 5 | atkarsk
# Processing Record 8 of Set 5 | vardo
# Processing Record 9 of Set 5 | suwannaphum
# Processing Record 10 of Set 5 | chiesanuova
# Processing Record 11 of Set 5 | kutum
# Processing Record 12 of Set 5 | peleduy
# Processing Record 13 of Set 5 | vanimo
# Processing Record 14 of Set 5 | gushikawa
# Processing Record 15 of Set 5 | lorengau
# Processing Record 16 of Set 5 | sembe
# Processing Record 17 of Set 5 | codrington
# Processing Record 18 of Set 5 | caravelas
# City not found. Skipping...
# Processing Record 19 of Set 5 | lagoa
# Processing Record 20 of Set 5 | college
# Processing Record 21 of Set 5 | faanui
# Processing Record 22 of Set 5 | comodoro rivadavia
# Processing Record 23 of Set 5 | provideniya
# Processing Record 24 of Set 5 | huarmey
# Processing Record 25 of Set 5 | inuvik
# Processing Record 26 of Set 5 | chumikan
# Processing Record 27 of Set 5 | lata
# Processing Record 28 of Set 5 | margate
# Processing Record 29 of Set 5 | hirara
# Processing Record 30 of Set 5 | raton
# Processing Record 31 of Set 5 | jacareacanga
# Processing Record 32 of Set 5 | lake charles
# Processing Record 33 of Set 5 | geraldton
# Processing Record 34 of Set 5 | berdigestyakh
# Processing Record 35 of Set 5 | broken hill
# Processing Record 36 of Set 5 | san juan del sur
# Processing Record 37 of Set 5 | mount isa
# Processing Record 38 of Set 5 | norman wells
# Processing Record 39 of Set 5 | cutervo
# City not found. Skipping...
# Processing Record 40 of Set 5 | the valley
# Processing Record 41 of Set 5 | hofn
# Processing Record 42 of Set 5 | kismayo
# Processing Record 43 of Set 5 | yunyang
# Processing Record 44 of Set 5 | jizan
# Processing Record 45 of Set 5 | pechory
# Processing Record 46 of Set 5 | kruisfontein
# Processing Record 47 of Set 5 | portlethen
# City not found. Skipping...
# Processing Record 48 of Set 5 | fereydun kenar
# Processing Record 49 of Set 5 | salalah
# Processing Record 0 of Set 6 | sturgis
# Processing Record 1 of Set 6 | abha
# Processing Record 2 of Set 6 | oxapampa
# Processing Record 3 of Set 6 | christchurch
# Processing Record 4 of Set 6 | victoria
# Processing Record 5 of Set 6 | bathsheba
# Processing Record 6 of Set 6 | key west
# City not found. Skipping...
# Processing Record 7 of Set 6 | naze
# Processing Record 8 of Set 6 | grindavik
# City not found. Skipping...
# Processing Record 9 of Set 6 | yeppoon
# Processing Record 10 of Set 6 | zhicheng
# Processing Record 11 of Set 6 | brae
# Processing Record 12 of Set 6 | chapais
# Processing Record 13 of Set 6 | chengde
# Processing Record 14 of Set 6 | horia
# Processing Record 15 of Set 6 | presidencia roque saenz pena
# Processing Record 16 of Set 6 | sarangani
# Processing Record 17 of Set 6 | saint simons
# Processing Record 18 of Set 6 | havelock
# Processing Record 19 of Set 6 | kaohsiung
# Processing Record 20 of Set 6 | tarakan
# Processing Record 21 of Set 6 | liuzhou
# Processing Record 22 of Set 6 | zhigansk
# Processing Record 23 of Set 6 | yanaul
# Processing Record 24 of Set 6 | bengkulu
# Processing Record 25 of Set 6 | dingle
# City not found. Skipping...
# Processing Record 26 of Set 6 | halifax
# Processing Record 27 of Set 6 | guozhen
# Processing Record 28 of Set 6 | teguldet
# Processing Record 29 of Set 6 | chhata
# Processing Record 30 of Set 6 | iqaluit
# Processing Record 31 of Set 6 | trinidad
# Processing Record 32 of Set 6 | kaeo
# Processing Record 33 of Set 6 | qusar
# Processing Record 34 of Set 6 | musoma
# Processing Record 35 of Set 6 | tecoanapa
# Processing Record 36 of Set 6 | praia da vitoria
# Processing Record 37 of Set 6 | salta
# Processing Record 38 of Set 6 | sambava
# City not found. Skipping...
# Processing Record 39 of Set 6 | gberia fotombu
# City not found. Skipping...
# Processing Record 40 of Set 6 | azamgarh
# Processing Record 41 of Set 6 | narsaq
# Processing Record 42 of Set 6 | areosa
# Processing Record 43 of Set 6 | bambous virieux
# Processing Record 44 of Set 6 | dunedin
# Processing Record 45 of Set 6 | calvinia
# Processing Record 46 of Set 6 | ukiah
# Processing Record 47 of Set 6 | oruro
# Processing Record 48 of Set 6 | camacha
# Processing Record 49 of Set 6 | kukmor
# Processing Record 0 of Set 7 | mantua
# Processing Record 1 of Set 7 | mariental
# Processing Record 2 of Set 7 | jining
# Processing Record 3 of Set 7 | kuusamo
# Processing Record 4 of Set 7 | llangefni
# Processing Record 5 of Set 7 | thabazimbi
# Processing Record 6 of Set 7 | jardim
# Processing Record 7 of Set 7 | constitucion
# Processing Record 8 of Set 7 | puerto escondido
# Processing Record 9 of Set 7 | yar-sale
# Processing Record 10 of Set 7 | holme
# Processing Record 11 of Set 7 | daru
# Processing Record 12 of Set 7 | puerto leguizamo
# Processing Record 13 of Set 7 | obregon
# Processing Record 14 of Set 7 | mitchell
# Processing Record 15 of Set 7 | tongliao
# Processing Record 16 of Set 7 | karratha
# Processing Record 17 of Set 7 | hambantota
# City not found. Skipping...
# Processing Record 18 of Set 7 | dauphin
# Processing Record 19 of Set 7 | whitehorse
# Processing Record 20 of Set 7 | olafsvik
# Processing Record 21 of Set 7 | san rafael
# Processing Record 22 of Set 7 | paamiut
# Processing Record 23 of Set 7 | namatanai
# Processing Record 24 of Set 7 | muhos
# Processing Record 25 of Set 7 | casa nova
# Processing Record 26 of Set 7 | castro
# Processing Record 27 of Set 7 | valparaiso
# Processing Record 28 of Set 7 | martapura
# Processing Record 29 of Set 7 | kisiwani
# Processing Record 30 of Set 7 | colquechaca
# Processing Record 31 of Set 7 | moroni
# Processing Record 32 of Set 7 | atikokan
# Processing Record 33 of Set 7 | oranjemund
# Processing Record 34 of Set 7 | campbell river
# Processing Record 35 of Set 7 | morgan city
# City not found. Skipping...
# Processing Record 36 of Set 7 | eregli
# Processing Record 37 of Set 7 | rudsar
# Processing Record 38 of Set 7 | te anau
# Processing Record 39 of Set 7 | vostok
# Processing Record 40 of Set 7 | meulaboh
# Processing Record 41 of Set 7 | bom jesus
# Processing Record 42 of Set 7 | lasem
# Processing Record 43 of Set 7 | taltal
# Processing Record 44 of Set 7 | tra vinh
# City not found. Skipping...
# Processing Record 45 of Set 7 | qujing
# Processing Record 46 of Set 7 | yantarnyy
# Processing Record 47 of Set 7 | haines junction
# Processing Record 48 of Set 7 | niamey
# Processing Record 49 of Set 7 | cozumel
# Processing Record 0 of Set 8 | port elizabeth
# Processing Record 1 of Set 8 | portland
# Processing Record 2 of Set 8 | kabanjahe
# Processing Record 3 of Set 8 | aljezur
# Processing Record 4 of Set 8 | amberley
# Processing Record 5 of Set 8 | deep river
# Processing Record 6 of Set 8 | rosetown
# Processing Record 7 of Set 8 | sinnamary
# Processing Record 8 of Set 8 | port lincoln
# Processing Record 9 of Set 8 | manta
# Processing Record 10 of Set 8 | kombissiri
# Processing Record 11 of Set 8 | magadan
# Processing Record 12 of Set 8 | bud
# Processing Record 13 of Set 8 | maceio
# Processing Record 14 of Set 8 | cabo rojo
# Processing Record 36 of Set 9 | asyut
# Processing Record 37 of Set 9 | leshukonskoye
# Processing Record 38 of Set 9 | berbera
# Processing Record 39 of Set 9 | yulara
# Processing Record 40 of Set 9 | clyde river
# Processing Record 41 of Set 9 | tovuz
# Processing Record 42 of Set 9 | fez
# City not found. Skipping...
# Processing Record 43 of Set 9 | roseburg
# Processing Record 44 of Set 9 | san cristobal
# Processing Record 45 of Set 9 | north bend
# Processing Record 46 of Set 9 | damghan
# Processing Record 47 of Set 9 | ledyard
# Processing Record 48 of Set 9 | osoyoos
# Processing Record 49 of Set 9 | gisborne
# Processing Record 0 of Set 10 | iralaya
# City not found. Skipping...
# Processing Record 1 of Set 10 | kindu
# Processing Record 2 of Set 10 | savannah bight
# Processing Record 3 of Set 10 | padang
# Processing Record 4 of Set 10 | rockwall
# Processing Record 5 of Set 10 | taupo
# Processing Record 6 of Set 10 | agapovka
# Processing Record 7 of Set 10 | nanfeng
# Processing Record 8 of Set 10 | francistown
# Processing Record 9 of Set 10 | sola
# Processing Record 10 of Set 10 | isla vista
# Processing Record 11 of Set 10 | letlhakeng
# Processing Record 12 of Set 10 | tura
# Processing Record 13 of Set 10 | culpeper
# Processing Record 14 of Set 10 | east london
# Processing Record 15 of Set 10 | lakatoro
# Processing Record 16 of Set 10 | rundu
# Processing Record 17 of Set 10 | baruun-urt
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 18 of Set 10 | alice springs
# Processing Record 19 of Set 10 | acuitzio
# Processing Record 20 of Set 10 | hearst
# Processing Record 21 of Set 10 | loughrea
# Processing Record 22 of Set 10 | pokhara
# Processing Record 23 of Set 10 | virginia beach
# Processing Record 24 of Set 10 | ormond beach
# Processing Record 25 of Set 10 | madera
# Processing Record 26 of Set 10 | saint-augustin
# City not found. Skipping...
# Processing Record 27 of Set 10 | abu dhabi
# Processing Record 28 of Set 10 | torbay
# Processing Record 29 of Set 10 | hokitika
# Processing Record 30 of Set 10 | ekhabi
# Processing Record 31 of Set 10 | shunyi
# Processing Record 32 of Set 10 | svetlaya
# Processing Record 33 of Set 10 | putina
# City not found. Skipping...
# Processing Record 34 of Set 10 | shitanjing
# Processing Record 35 of Set 10 | kajaani
# Processing Record 36 of Set 10 | alim
# Processing Record 37 of Set 10 | sakakah
# Processing Record 38 of Set 10 | san pedro masahuat
# Processing Record 39 of Set 10 | great yarmouth
# Processing Record 40 of Set 10 | aransas pass
# Processing Record 41 of Set 10 | gweta
# Processing Record 42 of Set 10 | tamiahua
# Processing Record 43 of Set 10 | pombas
# Processing Record 44 of Set 10 | ayagoz
# Processing Record 45 of Set 10 | divinopolis
# City not found. Skipping...
# Processing Record 46 of Set 10 | marzuq
# Processing Record 47 of Set 10 | mecca
# Processing Record 48 of Set 10 | lujan
# Processing Record 49 of Set 10 | hovd
# Processing Record 0 of Set 11 | bilma
# Processing Record 1 of Set 11 | bloomingdale
# Processing Record 2 of Set 11 | yumen
# Processing Record 3 of Set 11 | roebourne
# Processing Record 4 of Set 11 | zyryanovsk
# Processing Record 5 of Set 11 | snyder
# Processing Record 6 of Set 11 | fort nelson
# Processing Record 7 of Set 11 | alindao
# Processing Record 8 of Set 11 | soyo
# Processing Record 9 of Set 11 | santa isabel do rio negro
# Processing Record 10 of Set 11 | veraval
# Processing Record 11 of Set 11 | mangaratiba
# Processing Record 12 of Set 11 | yerbogachen
# City not found. Skipping...
# Processing Record 13 of Set 11 | korla
# Processing Record 14 of Set 11 | nerchinskiy zavod
# Processing Record 15 of Set 11 | sendafa
# Processing Record 16 of Set 11 | kobryn
# Processing Record 17 of Set 11 | porto walter
# Processing Record 18 of Set 11 | nantucket
# Processing Record 19 of Set 11 | kerrville
# Processing Record 20 of Set 11 | nechi
# Processing Record 21 of Set 11 | fenoarivo
# Processing Record 22 of Set 11 | abu kamal
# Processing Record 23 of Set 11 | sao joao da barra
# Processing Record 24 of Set 11 | sioux lookout
# Processing Record 25 of Set 11 | bojnurd
# City not found. Skipping...
# Processing Record 26 of Set 11 | sampit
# Processing Record 27 of Set 11 | port hedland
# Processing Record 28 of Set 11 | boditi
# Processing Record 29 of Set 11 | limbang
# Processing Record 30 of Set 11 | kabinda
# Processing Record 31 of Set 11 | humaita
# Processing Record 32 of Set 11 | port-cartier
# City not found. Skipping...
# Processing Record 33 of Set 11 | honiara
# Processing Record 34 of Set 11 | ayan
# Processing Record 35 of Set 11 | torit
# Processing Record 36 of Set 11 | santa helena
# Processing Record 37 of Set 11 | sitka
# Processing Record 38 of Set 11 | biskamzha
# Processing Record 39 of Set 11 | porto velho
# Processing Record 40 of Set 11 | ocean city
# Processing Record 41 of Set 11 | poum
# Processing Record 42 of Set 11 | deputatskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 11 | bertinoro
# Processing Record 44 of Set 11 | hohhot
# Processing Record 45 of Set 11 | salinopolis
# Processing Record 46 of Set 11 | worthington
# Processing Record 47 of Set 11 | qinzhou
# Processing Record 48 of Set 11 | omidiyeh
# Processing Record 49 of Set 11 | markova
# Processing Record 0 of Set 12 | dzaoudzi
# Processing Record 1 of Set 12 | stornoway
# Processing Record 2 of Set 12 | axim
# Processing Record 3 of Set 12 | baran
# ------------------------
# Data Retrieval Complete
# ------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
cities_df.to_csv(output_data_file)
cities_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Bluff -46.60  168.33     45.00        72          88       11.01
# 1  Bredasdorp -34.53   20.04     48.20        93          41        3.36
# 2    Dongzhen  22.38  110.94     78.03        82          44        1.34
# 3       Vaini -21.20 -175.20     78.80        88          40       12.75
# 4      Bethel  41.37  -73.41     72.39        53          75        5.82
#
#   Country        Date
# 0      NZ  1598907485
# 1      ZA  1598907500
# 2      CN  1598907519
# 3      TO  1598907485
# 4      US  1598907519

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
cities_df["Humidity"].max()

# There is no Humidity over 100, so all of this is not necessary
# Out:
# 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# put axes
lat = cities_df["Lat"]
max_temp = cities_df["Max Temp"]

# plot
plt.scatter(lat, max_temp, marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Max Temperature (08/31/20)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid()

# save
plt.savefig("CityLatitudeVsMaxTemperature.png")

# show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# put axes
humid = cities_df["Humidity"]

# plot
plt.scatter(lat, humid, marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Humidity (08/31/20)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid()

# save
plt.savefig("CityLatitudeVsHumidity.png")

# show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# put axes
cloud = cities_df["Cloudiness"]

# plot
plt.scatter(lat, cloud, marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Cloudiness (08/31/20)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid()

# save
plt.savefig("CityLatitudeVsCloudiness.png")

# show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# put axes
wind = cities_df["Wind Speed"]

# plot
plt.scatter(lat, wind, marker="o", facecolors="blue", edgecolors="black")
plt.title("City Latitude vs. Wind Speed (08/31/20)")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid()

# save
plt.savefig("CityLatitudeVsWindSpeed.png")

# show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# create new df's for northern and southern hempishere
north_hem_df = cities_df[cities_df['Lat'] > 0]
south_hem_df = cities_df[cities_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
from scipy.stats import linregress

x_value = north_hem_df['Lat']
y_value = north_hem_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (10, 40), color='red', fontsize= 14)
plt.title("Northern Hemisphere - Max Temp vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid()
plt.show()
plt.savefig("NorthMaxTempVsLat.png")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.6254054237353311

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_value = south_hem_df['Lat']
y_value = south_hem_df['Max Temp']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (-50, 90), color='red', fontsize= 14)
plt.title("Southern Hemisphere - Max Temp vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.grid()
plt.show()
plt.savefig("SouthMaxTempVsLat.png")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.6920361789313343

# %%
#Conclusion 1

print("Conclusion 1: The highest maximum temperatures are near the 0 value of the Latitude")
# Out:
# Conclusion 1: The highest maximum temperatures are near the 0 value of the Latitude

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = north_hem_df['Lat']
y_value = north_hem_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (50, 10), color='red', fontsize= 14)
plt.title("Northern Hemisphere - Humidity vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()
plt.savefig("NorthHumVsLat.png")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 7.6158896375358e-08

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_value = south_hem_df['Lat']
y_value = south_hem_df['Humidity']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (-50, 10), color='red', fontsize= 14)
plt.title("Southern Hemisphere - Humidity vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid()
plt.show()
plt.savefig("SouthHumVsLat.png")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.0001539441040677808

# %%
#Conclusion 2

print("Conclusion 2: Humidity and Latitude are not correlated")
# Out:
# Conclusion 2: Humidity and Latitude are not correlated

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = north_hem_df['Lat']
y_value = north_hem_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (8, 30), color='red', fontsize= 14)
plt.title("Northern Hemisphere - Cloudiness vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()
plt.savefig("NorthCloudVsLat.png")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 7.175624174076949e-05

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_value = south_hem_df['Lat']
y_value = south_hem_df['Cloudiness']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (-50, 26), color='red', fontsize= 14)
plt.title("Southern Hemisphere - Cloudiness vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid()
plt.show()
plt.savefig("SouthCloudVsLat.png")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.010964522290626017

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = north_hem_df['Lat']
y_value = north_hem_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (40, 35), color='red', fontsize= 14)
plt.title("Northern Hemisphere - Wind Speed vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()
plt.savefig("NorthWindVsLat.png")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.006030145249798099

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_value = south_hem_df['Lat']
y_value = south_hem_df['Wind Speed']

(slope, intercept, rvalue, pvalue, stderr)= linregress(x_value, y_value)
regress_values= x_value *slope + intercept
line_eq=f"y={round(slope,2)}x + {round(intercept,2)}"
plt.scatter(x_value, y_value, marker="o", facecolors="blue", edgecolors="black")
plt.plot(x_value, regress_values, color='red')
plt.annotate(line_eq, (-47, 28), color='red', fontsize= 14)
plt.title("Southern Hemisphere - Wind Speed vs. Latitude (08/31/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()
plt.savefig("SouthWindVsLat.png")
print(f"The r-squared is: {rvalue**2}")
# Out:
# The r-squared is: 0.0006716444346347051

# %%
#Conclusion 3

print("Conclusion 3: There is no trend in the Wind Speed compared to the latitude")
# Out:
# Conclusion 3: There is no trend in the Wind Speed compared to the latitude
